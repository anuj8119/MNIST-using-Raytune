# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.0.3-py3-none-any.whl (348 kB)
#      |████████████████████████████████| 348 kB 35.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 70.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.1)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.0 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (6.0)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: importlib-metadata<5.0.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (4.13.0)
# Requirement already satisfied: scipy<1.9.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.41)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting Mako
#   Downloading Mako-1.2.3-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.9 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic>=1.5.0->optuna) (5.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.3.0->optuna) (1.1.3.post0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.6 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.10.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 67.2 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 74.2 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.4.1)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (22.1.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=08a61feca1686792a1e8cbccc86f3aad42a4853b26b6609f856a9e1d6c1b2eff
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.3 alembic-1.8.1 autopage-0.5.1 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.2 colorlog-6.7.0 optuna-3.0.3 pbr-5.10.0 pyperclip-1.8.2 stevedore-3.5.1

# %%
pip install "ray[tune]" optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray[tune]
#   Downloading ray-2.0.0-cp37-cp37m-manylinux2014_x86_64.whl (59.4 MB)
#      |████████████████████████████████| 59.4 MB 1.2 MB/s
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (3.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.1)
# Requirement already satisfied: importlib-metadata<5.0.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (4.13.0)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: scipy<1.9.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.41)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic>=1.5.0->optuna) (5.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.3.0->optuna) (1.1.3.post0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.1)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.10.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.4.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (22.1.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.2.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.23.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.17.3)
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 27.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.8.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.3.1)
# Collecting virtualenv
#   Downloading virtualenv-20.16.5-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 11.6 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (4.3.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (0.8.10)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 74.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.3.5)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]) (1.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2022.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (1.24.3)
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 69.7 MB/s
# Installing collected packages: platformdirs, distlib, virtualenv, grpcio, tensorboardX, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.49.1
#     Uninstalling grpcio-1.49.1:
#       Successfully uninstalled grpcio-1.49.1
# Successfully installed distlib-0.3.6 grpcio-1.43.0 platformdirs-2.5.2 ray-2.0.0 tensorboardX-2.5.1 virtualenv-20.16.5

# %%
pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ray in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray) (3.17.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray) (1.43.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray) (6.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray) (3.8.0)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.7/dist-packages (from ray) (20.16.5)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray) (1.2.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray) (22.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from ray) (4.1.1)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (4.13.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray) (0.3.6)

# %%
pip install 'ray[tune]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (4.3.3)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.43.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.17.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (6.0)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (20.16.5)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.21.6)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (22.1.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.0.4)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (7.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (4.1.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (0.8.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.3.5)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.5.1)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]) (1.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (5.10.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (4.13.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray[tune]) (3.9.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (1.24.3)
# Requirement already satisfied: distlib<1,>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray[tune]) (0.3.6)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray[tune]) (2.5.2)

# %%
import torch
import torch.optim as optim
from ray.tune.examples.mnist_pytorch import get_data_loaders, ConvNet, train, test
from ray import tune
from ray.tune.suggest.optuna import OptunaSearch


def train_mnist(config):
   use_cuda = torch.cuda.is_available()
   device = torch.device("cuda" if use_cuda else "cpu")
   train_loader, test_loader = get_data_loaders()
   model = ConvNet().to(device)

   optimizer = optim.SGD(
       model.parameters(), lr=config["lr"], momentum=config["momentum"])

   for i in range(20):
       train(model, optimizer, train_loader, device)
       acc = test(model, test_loader, device)
       tune.report(mean_accuracy=acc)


import time
start = time.time()
analysis = tune.run(
   train_mnist,
   config={
       "lr": tune.loguniform(1e-4, 1e-1),
       "momentum": tune.uniform(0.1, 0.9),
   },
   metric="mean_accuracy",
   mode="max",
   search_alg=OptunaSearch(),
   num_samples=10)
taken = time.time() - start
print(f"Time taken: {taken:.2f} seconds.")
print(f"Best config: {analysis.best_config}")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
#   """
# 2022-10-20 05:13:38,056	INFO worker.py:1518 -- Started a local Ray instance.
# 2022-10-20 05:13:39,455	WARNING function_trainable.py:620 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# /usr/local/lib/python3.7/dist-packages/ray/tune/search/optuna/optuna_search.py:674: FutureWarning: LogUniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   domain.lower, domain.upper
# /usr/local/lib/python3.7/dist-packages/ray/tune/search/optuna/optuna_search.py:683: FutureWarning: UniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   domain.lower, domain.upper
# [I 2022-10-20 05:13:39,473] A new study created in memory with name: optuna
# == Status ==<br>Current time: 2022-10-20 05:14:25 (running for 00:00:45.62)<br>Memory usage on this node: 1.5/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.29 GiB heap, 0.0/3.65 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 02992a56 with mean_accuracy=0.93125 and parameters={'lr': 0.02694406454004187, 'momentum': 0.7642837808647588}<br>Result logdir: /root/ray_results/train_mnist_2022-10-20_05-13-39<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc           </th><th style="text-align: right;">         lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_f55c3f5e</td><td>TERMINATED</td><td>172.28.0.2:403</td><td style="text-align: right;">0.000103276</td><td style="text-align: right;">  0.269313</td><td style="text-align: right;">0.078125</td><td style="text-align: right;">    20</td><td style="text-align: right;">        11.2503 </td></tr>
# <tr><td>train_mnist_f7b47c62</td><td>TERMINATED</td><td>172.28.0.2:435</td><td style="text-align: right;">0.000456005</td><td style="text-align: right;">  0.306856</td><td style="text-align: right;">0.11875 </td><td style="text-align: right;">    20</td><td style="text-align: right;">         7.04032</td></tr>
# <tr><td>train_mnist_f7b8961c</td><td>TERMINATED</td><td>172.28.0.2:403</td><td style="text-align: right;">0.000295522</td><td style="text-align: right;">  0.787548</td><td style="text-align: right;">0.446875</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.93791</td></tr>
# <tr><td>train_mnist_fe725880</td><td>TERMINATED</td><td>172.28.0.2:435</td><td style="text-align: right;">0.0754731  </td><td style="text-align: right;">  0.891985</td><td style="text-align: right;">0.928125</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.99318</td></tr>
# <tr><td>train_mnist_fefab0fe</td><td>TERMINATED</td><td>172.28.0.2:403</td><td style="text-align: right;">0.000132099</td><td style="text-align: right;">  0.836265</td><td style="text-align: right;">0.115625</td><td style="text-align: right;">    20</td><td style="text-align: right;">         7.02072</td></tr>
# <tr><td>train_mnist_02992a56</td><td>TERMINATED</td><td>172.28.0.2:435</td><td style="text-align: right;">0.0269441  </td><td style="text-align: right;">  0.764284</td><td style="text-align: right;">0.93125 </td><td style="text-align: right;">    20</td><td style="text-align: right;">         7.61987</td></tr>
# <tr><td>train_mnist_032a8672</td><td>TERMINATED</td><td>172.28.0.2:403</td><td style="text-align: right;">0.0365155  </td><td style="text-align: right;">  0.122019</td><td style="text-align: right;">0.8625  </td><td style="text-align: right;">    20</td><td style="text-align: right;">         8.75051</td></tr>
# <tr><td>train_mnist_06cbd204</td><td>TERMINATED</td><td>172.28.0.2:435</td><td style="text-align: right;">0.000104987</td><td style="text-align: right;">  0.617589</td><td style="text-align: right;">0.146875</td><td style="text-align: right;">    20</td><td style="text-align: right;">         8.19955</td></tr>
# <tr><td>train_mnist_07b9f132</td><td>TERMINATED</td><td>172.28.0.2:403</td><td style="text-align: right;">0.000129441</td><td style="text-align: right;">  0.209684</td><td style="text-align: right;">0.128125</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.97476</td></tr>
# <tr><td>train_mnist_0c06689c</td><td>TERMINATED</td><td>172.28.0.2:435</td><td style="text-align: right;">0.0482491  </td><td style="text-align: right;">  0.488474</td><td style="text-align: right;">0.903125</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.51607</td></tr>
# </tbody>
# </table><br><br>
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: LogUniformDistribution(high=0.1, low=0.0001) is deprecated and internally converted to FloatDistribution(high=0.1, log=True, low=0.0001, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: UniformDistribution(high=0.9, low=0.1) is deprecated and internally converted to FloatDistribution(high=0.9, log=False, low=0.1, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
#   7%|▋         | 655360/9912422 [00:00<00:01, 6392286.48it/s]
#  25%|██▍       | 2457600/9912422 [00:00<00:00, 10546624.88it/s]
# 100%|██████████| 9912422/9912422 [00:00<00:00, 22181709.91it/s]
# (train_mnist pid=403) Extracting /root/data/MNIST/raw/train-images-idx3-ubyte.gz to /root/data/MNIST/raw
# (train_mnist pid=403)
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/data/MNIST/raw/train-labels-idx1-ubyte.gz
# (train_mnist pid=403) Extracting /root/data/MNIST/raw/train-labels-idx1-ubyte.gz to /root/data/MNIST/raw
# (train_mnist pid=403)
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 126446444.49it/s]
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# 100%|██████████| 1648877/1648877 [00:00<00:00, 90894520.70it/s]
# (train_mnist pid=403) Extracting /root/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/data/MNIST/raw
# (train_mnist pid=403)
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# (train_mnist pid=403) Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# (train_mnist pid=403) Extracting /root/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/data/MNIST/raw
# (train_mnist pid=403)
# 100%|██████████| 4542/4542 [00:00<00:00, 25778794.00it/s]
# Result for train_mnist_f55c3f5e:
#   date: 2022-10-20_05-13-48
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.0875
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 4.682225942611694
#   time_this_iter_s: 4.682225942611694
#   time_total_s: 4.682225942611694
#   timestamp: 1666242828
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f55c3f5e
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_f7b47c62:
#   date: 2022-10-20_05-13-49
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.09375
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 0.5093798637390137
#   time_this_iter_s: 0.5093798637390137
#   time_total_s: 0.5093798637390137
#   timestamp: 1666242829
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f7b47c62
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_f55c3f5e:
#   date: 2022-10-20_05-13-53
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.08125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 9.849273204803467
#   time_this_iter_s: 0.3350045680999756
#   time_total_s: 9.849273204803467
#   timestamp: 1666242833
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f55c3f5e
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_f7b47c62:
#   date: 2022-10-20_05-13-54
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.09375
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 5.673961639404297
#   time_this_iter_s: 0.3289930820465088
#   time_total_s: 5.673961639404297
#   timestamp: 1666242834
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f7b47c62
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_f55c3f5e:
#   date: 2022-10-20_05-13-55
#   done: true
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   experiment_tag: 1_lr=0.0001,momentum=0.2693
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.078125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 11.250265836715698
#   time_this_iter_s: 0.34993934631347656
#   time_total_s: 11.250265836715698
#   timestamp: 1666242835
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f55c3f5e
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_f7b8961c:
#   date: 2022-10-20_05-13-55
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.053125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 0.38802146911621094
#   time_this_iter_s: 0.38802146911621094
#   time_total_s: 0.38802146911621094
#   timestamp: 1666242835
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f7b8961c
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_f7b47c62:
#   date: 2022-10-20_05-13-55
#   done: true
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   experiment_tag: 2_lr=0.0005,momentum=0.3069
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.11875
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 7.040321588516235
#   time_this_iter_s: 0.34662723541259766
#   time_total_s: 7.040321588516235
#   timestamp: 1666242835
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f7b47c62
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_fe725880:
#   date: 2022-10-20_05-13-56
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.625
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 0.3940293788909912
#   time_this_iter_s: 0.3940293788909912
#   time_total_s: 0.3940293788909912
#   timestamp: 1666242836
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fe725880
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_f7b8961c:
#   date: 2022-10-20_05-14-00
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.3
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 5.553210020065308
#   time_this_iter_s: 0.3388938903808594
#   time_total_s: 5.553210020065308
#   timestamp: 1666242840
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f7b8961c
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_fe725880:
#   date: 2022-10-20_05-14-01
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.909375
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 5.579770565032959
#   time_this_iter_s: 0.3442106246948242
#   time_total_s: 5.579770565032959
#   timestamp: 1666242841
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: fe725880
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_f7b8961c:
#   date: 2022-10-20_05-14-02
#   done: true
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   experiment_tag: 3_lr=0.0003,momentum=0.7875
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.446875
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 6.937908411026001
#   time_this_iter_s: 0.3474729061126709
#   time_total_s: 6.937908411026001
#   timestamp: 1666242842
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f7b8961c
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_fefab0fe:
#   date: 2022-10-20_05-14-02
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.08125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 0.38274121284484863
#   time_this_iter_s: 0.38274121284484863
#   time_total_s: 0.38274121284484863
#   timestamp: 1666242842
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fefab0fe
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_fe725880:
#   date: 2022-10-20_05-14-02
#   done: true
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   experiment_tag: 4_lr=0.0755,momentum=0.8920
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.928125
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 6.9931793212890625
#   time_this_iter_s: 0.34903860092163086
#   time_total_s: 6.9931793212890625
#   timestamp: 1666242842
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: fe725880
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_02992a56:
#   date: 2022-10-20_05-14-03
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.534375
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 0.40464234352111816
#   time_this_iter_s: 0.40464234352111816
#   time_total_s: 0.40464234352111816
#   timestamp: 1666242843
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 02992a56
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_fefab0fe:
#   date: 2022-10-20_05-14-07
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.115625
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 5.629988431930542
#   time_this_iter_s: 0.34531712532043457
#   time_total_s: 5.629988431930542
#   timestamp: 1666242847
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: fefab0fe
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_02992a56:
#   date: 2022-10-20_05-14-08
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.890625
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 5.630848169326782
#   time_this_iter_s: 0.3356926441192627
#   time_total_s: 5.630848169326782
#   timestamp: 1666242848
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 02992a56
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_fefab0fe:
#   date: 2022-10-20_05-14-09
#   done: true
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   experiment_tag: 5_lr=0.0001,momentum=0.8363
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.115625
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 7.020724296569824
#   time_this_iter_s: 0.3386075496673584
#   time_total_s: 7.020724296569824
#   timestamp: 1666242849
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: fefab0fe
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_032a8672:
#   date: 2022-10-20_05-14-09
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.61875
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 0.4941709041595459
#   time_this_iter_s: 0.4941709041595459
#   time_total_s: 0.4941709041595459
#   timestamp: 1666242849
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 032a8672
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_02992a56:
#   date: 2022-10-20_05-14-10
#   done: true
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   experiment_tag: 6_lr=0.0269,momentum=0.7643
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.93125
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 7.619871616363525
#   time_this_iter_s: 0.6000359058380127
#   time_total_s: 7.619871616363525
#   timestamp: 1666242850
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 02992a56
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_06cbd204:
#   date: 2022-10-20_05-14-11
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.096875
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 0.6426436901092529
#   time_this_iter_s: 0.6426436901092529
#   time_total_s: 0.6426436901092529
#   timestamp: 1666242851
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 06cbd204
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_032a8672:
#   date: 2022-10-20_05-14-14
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 11
#   mean_accuracy: 0.828125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 5.672769546508789
#   time_this_iter_s: 0.34287071228027344
#   time_total_s: 5.672769546508789
#   timestamp: 1666242854
#   timesteps_since_restore: 0
#   training_iteration: 11
#   trial_id: 032a8672
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_06cbd204:
#   date: 2022-10-20_05-14-16
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 13
#   mean_accuracy: 0.128125
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 5.8101561069488525
#   time_this_iter_s: 0.338681697845459
#   time_total_s: 5.8101561069488525
#   timestamp: 1666242856
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: 06cbd204
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_032a8672:
#   date: 2022-10-20_05-14-17
#   done: true
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   experiment_tag: 7_lr=0.0365,momentum=0.1220
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.8625
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 8.750508546829224
#   time_this_iter_s: 0.336897611618042
#   time_total_s: 8.750508546829224
#   timestamp: 1666242857
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 032a8672
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_07b9f132:
#   date: 2022-10-20_05-14-18
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.084375
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 0.39321160316467285
#   time_this_iter_s: 0.39321160316467285
#   time_total_s: 0.39321160316467285
#   timestamp: 1666242858
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 07b9f132
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_06cbd204:
#   date: 2022-10-20_05-14-18
#   done: true
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   experiment_tag: 8_lr=0.0001,momentum=0.6176
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.146875
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 8.199549674987793
#   time_this_iter_s: 0.34274768829345703
#   time_total_s: 8.199549674987793
#   timestamp: 1666242858
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 06cbd204
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_0c06689c:
#   date: 2022-10-20_05-14-19
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.31875
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 0.37776780128479004
#   time_this_iter_s: 0.37776780128479004
#   time_total_s: 0.37776780128479004
#   timestamp: 1666242859
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0c06689c
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_07b9f132:
#   date: 2022-10-20_05-14-23
#   done: false
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.096875
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 5.581335544586182
#   time_this_iter_s: 0.3401205539703369
#   time_total_s: 5.581335544586182
#   timestamp: 1666242863
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 07b9f132
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_0c06689c:
#   date: 2022-10-20_05-14-24
#   done: false
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.91875
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 5.521936655044556
#   time_this_iter_s: 0.3311588764190674
#   time_total_s: 5.521936655044556
#   timestamp: 1666242864
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 0c06689c
#   warmup_time: 0.004791259765625
#
# Result for train_mnist_07b9f132:
#   date: 2022-10-20_05-14-24
#   done: true
#   experiment_id: 5aa9edd8bb0b4deb88b94e6c3801e738
#   experiment_tag: 9_lr=0.0001,momentum=0.2097
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.128125
#   node_ip: 172.28.0.2
#   pid: 403
#   time_since_restore: 6.9747583866119385
#   time_this_iter_s: 0.33864593505859375
#   time_total_s: 6.9747583866119385
#   timestamp: 1666242864
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 07b9f132
#   warmup_time: 0.04597115516662598
#
# Result for train_mnist_0c06689c:
#   date: 2022-10-20_05-14-25
#   done: true
#   experiment_id: 24b465f00c704c4189f44c82848b624f
#   experiment_tag: 10_lr=0.0482,momentum=0.4885
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.903125
#   node_ip: 172.28.0.2
#   pid: 435
#   time_since_restore: 6.516071796417236
#   time_this_iter_s: 0.18589210510253906
#   time_total_s: 6.516071796417236
#   timestamp: 1666242865
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 0c06689c
#   warmup_time: 0.004791259765625
# 2022-10-20 05:14:25,537	INFO tune.py:759 -- Total run time: 46.09 seconds (45.61 seconds for the tuning loop).
# Time taken: 49.84 seconds.
# Best config: {'lr': 0.02694406454004187, 'momentum': 0.7642837808647588}

# %%
search_space ={
        "steps":100,
        "width": tune.uniform(0,20),
        "height":tune.uniform(-100,100)
    }
    analysis = tune.Tuner(
        objectiveFunc,
        tune_config=tune.TuneConfig(
            metric="mean_loss",
            mode="min"
            search_alg=OptunaSearch()
            num_samples=n_trials
        )
        param_space= search_space
        )
        result= analysis.fit()
        #taken = time.time() - start
        # print(f"Time taken: {taken:.2f} seconds.")
        print(f"Best config: {analysis.best_config}")

# %%
import torch
import torch.optim as optim
from ray.tune.examples.mnist_pytorch import get_data_loaders, ConvNet, train, test
from ray import tune
from ray.tune.suggest.optuna import OptunaSearch


def train_mnist(config):
   use_cuda = torch.cuda.is_available()
   device = torch.device("cuda" if use_cuda else "cpu")
   train_loader, test_loader = get_data_loaders()
   model = ConvNet().to(device)

   optimizer = optim.SGD(
       model.parameters(), lr=config["lr"], momentum=config["momentum"])

   for i in range(20):
       train(model, optimizer, train_loader, device)
       acc = test(model, test_loader, device)
       tune.report(mean_accuracy=acc)

search_space ={
        "steps":100,
        "width": tune.uniform(0,20),
        "height":tune.uniform(-100,100),
        "lr": tune.loguniform(1e-4, 1e-1),
        "momentum": tune.uniform(0.1, 0.9),
     }


import time
start = time.time()
analysis = tune.Tuner(
   train_mnist,
   tune_config=tune.TuneConfig(
       metric="mean_accuracy",
       mode="max",
       search_alg=OptunaSearch(),
       num_samples=10
   #search_alg=ConcurrencyLimiter(OptunaSearch(),max_concurrent=4)
   #num_samples=n_trials)
   ),
   param_space= search_space
        )
result= analysis.fit()
taken = time.time() - start
best_params = result.get_best_result()
print(f"Time taken: {taken:.2f} seconds.")
print(f"Best config: {best_params}")
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/tune/search/optuna/optuna_search.py:683: FutureWarning: UniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   domain.lower, domain.upper
# /usr/local/lib/python3.7/dist-packages/ray/tune/search/optuna/optuna_search.py:674: FutureWarning: LogUniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   domain.lower, domain.upper
# [I 2022-10-20 05:42:19,556] A new study created in memory with name: optuna
# == Status ==<br>Current time: 2022-10-20 05:43:06 (running for 00:00:47.16)<br>Memory usage on this node: 1.7/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.29 GiB heap, 0.0/3.65 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: fe3210aa with mean_accuracy=0.909375 and parameters={'steps': 100, 'width': 5.555917946413185, 'height': 11.454337658750788, 'lr': 0.08495958767364636, 'momentum': 0.4734163529887274}<br>Result logdir: /root/ray_results/train_mnist_2022-10-20_05-42-19<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc            </th><th style="text-align: right;">  height</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">   width</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_f6669de6</td><td>TERMINATED</td><td>172.28.0.2:1123</td><td style="text-align: right;"> 28.6597</td><td style="text-align: right;">0.000127883</td><td style="text-align: right;">  0.249355</td><td style="text-align: right;">18.8046 </td><td style="text-align: right;">0.115625</td><td style="text-align: right;">    20</td><td style="text-align: right;">         7.02238</td></tr>
# <tr><td>train_mnist_f80cda98</td><td>TERMINATED</td><td>172.28.0.2:1158</td><td style="text-align: right;">-65.3786</td><td style="text-align: right;">0.000215123</td><td style="text-align: right;">  0.131849</td><td style="text-align: right;">14.2207 </td><td style="text-align: right;">0.309375</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.97444</td></tr>
# <tr><td>train_mnist_f8121d46</td><td>TERMINATED</td><td>172.28.0.2:1123</td><td style="text-align: right;">-52.9823</td><td style="text-align: right;">0.000861941</td><td style="text-align: right;">  0.639764</td><td style="text-align: right;">13.6356 </td><td style="text-align: right;">0.515625</td><td style="text-align: right;">    20</td><td style="text-align: right;">         7.29433</td></tr>
# <tr><td>train_mnist_fc3fdd54</td><td>TERMINATED</td><td>172.28.0.2:1158</td><td style="text-align: right;">-36.0462</td><td style="text-align: right;">0.00391828 </td><td style="text-align: right;">  0.22711 </td><td style="text-align: right;">18.1662 </td><td style="text-align: right;">0.771875</td><td style="text-align: right;">    20</td><td style="text-align: right;">         8.79602</td></tr>
# <tr><td>train_mnist_fe3210aa</td><td>TERMINATED</td><td>172.28.0.2:1123</td><td style="text-align: right;"> 11.4543</td><td style="text-align: right;">0.0849596  </td><td style="text-align: right;">  0.473416</td><td style="text-align: right;"> 5.55592</td><td style="text-align: right;">0.909375</td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.79679</td></tr>
# <tr><td>train_mnist_009dc1e0</td><td>TERMINATED</td><td>172.28.0.2:1158</td><td style="text-align: right;"> 94.3079</td><td style="text-align: right;">0.00757661 </td><td style="text-align: right;">  0.493351</td><td style="text-align: right;"> 2.09597</td><td style="text-align: right;">0.853125</td><td style="text-align: right;">    20</td><td style="text-align: right;">         8.99407</td></tr>
# <tr><td>train_mnist_03755efa</td><td>TERMINATED</td><td>172.28.0.2:1123</td><td style="text-align: right;">-68.3622</td><td style="text-align: right;">0.000426235</td><td style="text-align: right;">  0.437882</td><td style="text-align: right;">12.3653 </td><td style="text-align: right;">0.08125 </td><td style="text-align: right;">    20</td><td style="text-align: right;">         8.13778</td></tr>
# <tr><td>train_mnist_067b0708</td><td>TERMINATED</td><td>172.28.0.2:1158</td><td style="text-align: right;"> 12.1993</td><td style="text-align: right;">0.00349133 </td><td style="text-align: right;">  0.142255</td><td style="text-align: right;">18.4613 </td><td style="text-align: right;">0.70625 </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.33955</td></tr>
# <tr><td>train_mnist_08d986fa</td><td>TERMINATED</td><td>172.28.0.2:1123</td><td style="text-align: right;"> 95.4983</td><td style="text-align: right;">0.00233922 </td><td style="text-align: right;">  0.685988</td><td style="text-align: right;">12.8862 </td><td style="text-align: right;">0.8     </td><td style="text-align: right;">    20</td><td style="text-align: right;">        10      </td></tr>
# <tr><td>train_mnist_0b5901d0</td><td>TERMINATED</td><td>172.28.0.2:1158</td><td style="text-align: right;">-55.109 </td><td style="text-align: right;">0.00294445 </td><td style="text-align: right;">  0.713272</td><td style="text-align: right;">10.5164 </td><td style="text-align: right;">0.859375</td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.82846</td></tr>
# </tbody>
# </table><br><br>
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: UniformDistribution(high=20.0, low=0.0) is deprecated and internally converted to FloatDistribution(high=20.0, log=False, low=0.0, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: UniformDistribution(high=100.0, low=-100.0) is deprecated and internally converted to FloatDistribution(high=100.0, log=False, low=-100.0, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: LogUniformDistribution(high=0.1, low=0.0001) is deprecated and internally converted to FloatDistribution(high=0.1, log=True, low=0.0001, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/optuna/distributions.py:766: FutureWarning: UniformDistribution(high=0.9, low=0.1) is deprecated and internally converted to FloatDistribution(high=0.9, log=False, low=0.1, step=None). See https://github.com/optuna/optuna/issues/2941.
#   warnings.warn(message, FutureWarning)
# Result for train_mnist_f6669de6:
#   date: 2022-10-20_05-42-22
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.10625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 0.5981571674346924
#   time_this_iter_s: 0.5981571674346924
#   time_total_s: 0.5981571674346924
#   timestamp: 1666244542
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f6669de6
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_f80cda98:
#   date: 2022-10-20_05-42-26
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.103125
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 0.5095155239105225
#   time_this_iter_s: 0.5095155239105225
#   time_total_s: 0.5095155239105225
#   timestamp: 1666244546
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f80cda98
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_f6669de6:
#   date: 2022-10-20_05-42-27
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.140625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 5.6636786460876465
#   time_this_iter_s: 0.3322269916534424
#   time_total_s: 5.6636786460876465
#   timestamp: 1666244547
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f6669de6
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_f6669de6:
#   date: 2022-10-20_05-42-29
#   done: true
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   experiment_tag: 1_height=28.6597,lr=0.0001,momentum=0.2494,steps=100,width=18.8046
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.115625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 7.022375106811523
#   time_this_iter_s: 0.3362853527069092
#   time_total_s: 7.022375106811523
#   timestamp: 1666244549
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f6669de6
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_f8121d46:
#   date: 2022-10-20_05-42-29
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.08125
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 0.42780375480651855
#   time_this_iter_s: 0.42780375480651855
#   time_total_s: 0.42780375480651855
#   timestamp: 1666244549
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f8121d46
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_f80cda98:
#   date: 2022-10-20_05-42-31
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.234375
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 5.604411363601685
#   time_this_iter_s: 0.3386244773864746
#   time_total_s: 5.604411363601685
#   timestamp: 1666244551
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f80cda98
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_f80cda98:
#   date: 2022-10-20_05-42-32
#   done: true
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   experiment_tag: 2_height=-65.3786,lr=0.0002,momentum=0.1318,steps=100,width=14.2207
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.309375
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 6.9744367599487305
#   time_this_iter_s: 0.3307209014892578
#   time_total_s: 6.9744367599487305
#   timestamp: 1666244552
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f80cda98
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_fc3fdd54:
#   date: 2022-10-20_05-42-33
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.1375
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 0.4115610122680664
#   time_this_iter_s: 0.4115610122680664
#   time_total_s: 0.4115610122680664
#   timestamp: 1666244553
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fc3fdd54
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_f8121d46:
#   date: 2022-10-20_05-42-35
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 16
#   mean_accuracy: 0.425
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 5.670173168182373
#   time_this_iter_s: 0.3387596607208252
#   time_total_s: 5.670173168182373
#   timestamp: 1666244555
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: f8121d46
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_f8121d46:
#   date: 2022-10-20_05-42-36
#   done: true
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   experiment_tag: 3_height=-52.9823,lr=0.0009,momentum=0.6398,steps=100,width=13.6356
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.515625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 7.294325828552246
#   time_this_iter_s: 0.6082303524017334
#   time_total_s: 7.294325828552246
#   timestamp: 1666244556
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: f8121d46
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_fe3210aa:
#   date: 2022-10-20_05-42-37
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.60625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 1.2875769138336182
#   time_this_iter_s: 1.2875769138336182
#   time_total_s: 1.2875769138336182
#   timestamp: 1666244557
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fe3210aa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_fc3fdd54:
#   date: 2022-10-20_05-42-38
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 13
#   mean_accuracy: 0.696875
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 5.705003976821899
#   time_this_iter_s: 0.3729841709136963
#   time_total_s: 5.705003976821899
#   timestamp: 1666244558
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: fc3fdd54
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_fc3fdd54:
#   date: 2022-10-20_05-42-41
#   done: true
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   experiment_tag: 4_height=-36.0462,lr=0.0039,momentum=0.2271,steps=100,width=18.1662
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.771875
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 8.79602313041687
#   time_this_iter_s: 0.66623854637146
#   time_total_s: 8.79602313041687
#   timestamp: 1666244561
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: fc3fdd54
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_009dc1e0:
#   date: 2022-10-20_05-42-42
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.15625
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 0.7869935035705566
#   time_this_iter_s: 0.7869935035705566
#   time_total_s: 0.7869935035705566
#   timestamp: 1666244562
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 009dc1e0
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_fe3210aa:
#   date: 2022-10-20_05-42-43
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 12
#   mean_accuracy: 0.890625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 6.627487897872925
#   time_this_iter_s: 0.7046880722045898
#   time_total_s: 6.627487897872925
#   timestamp: 1666244563
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: fe3210aa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_fe3210aa:
#   date: 2022-10-20_05-42-46
#   done: true
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   experiment_tag: 5_height=11.4543,lr=0.0850,momentum=0.4734,steps=100,width=5.5559
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.909375
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 9.796791076660156
#   time_this_iter_s: 0.3760716915130615
#   time_total_s: 9.796791076660156
#   timestamp: 1666244566
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: fe3210aa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_03755efa:
#   date: 2022-10-20_05-42-47
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.0375
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 0.5416550636291504
#   time_this_iter_s: 0.5416550636291504
#   time_total_s: 0.5416550636291504
#   timestamp: 1666244567
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 03755efa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_009dc1e0:
#   date: 2022-10-20_05-42-47
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 13
#   mean_accuracy: 0.840625
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 6.028074741363525
#   time_this_iter_s: 0.4224584102630615
#   time_total_s: 6.028074741363525
#   timestamp: 1666244567
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: 009dc1e0
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_009dc1e0:
#   date: 2022-10-20_05-42-50
#   done: true
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   experiment_tag: 6_height=94.3079,lr=0.0076,momentum=0.4934,steps=100,width=2.0960
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.853125
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 8.994069576263428
#   time_this_iter_s: 0.4055511951446533
#   time_total_s: 8.994069576263428
#   timestamp: 1666244570
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 009dc1e0
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_067b0708:
#   date: 2022-10-20_05-42-50
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.25
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 0.4527308940887451
#   time_this_iter_s: 0.4527308940887451
#   time_total_s: 0.4527308940887451
#   timestamp: 1666244570
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 067b0708
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_03755efa:
#   date: 2022-10-20_05-42-52
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 14
#   mean_accuracy: 0.053125
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 5.821127891540527
#   time_this_iter_s: 0.35793280601501465
#   time_total_s: 5.821127891540527
#   timestamp: 1666244572
#   timesteps_since_restore: 0
#   training_iteration: 14
#   trial_id: 03755efa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_03755efa:
#   date: 2022-10-20_05-42-54
#   done: true
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   experiment_tag: 7_height=-68.3622,lr=0.0004,momentum=0.4379,steps=100,width=12.3653
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.08125
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 8.137775182723999
#   time_this_iter_s: 0.36193156242370605
#   time_total_s: 8.137775182723999
#   timestamp: 1666244574
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 03755efa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_08d986fa:
#   date: 2022-10-20_05-42-55
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.040625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 0.4972050189971924
#   time_this_iter_s: 0.4972050189971924
#   time_total_s: 0.4972050189971924
#   timestamp: 1666244575
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 08d986fa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_067b0708:
#   date: 2022-10-20_05-42-56
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 14
#   mean_accuracy: 0.625
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 5.870469808578491
#   time_this_iter_s: 0.5336294174194336
#   time_total_s: 5.870469808578491
#   timestamp: 1666244576
#   timesteps_since_restore: 0
#   training_iteration: 14
#   trial_id: 067b0708
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_067b0708:
#   date: 2022-10-20_05-42-59
#   done: true
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   experiment_tag: 8_height=12.1993,lr=0.0035,momentum=0.1423,steps=100,width=18.4613
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.70625
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 9.339545965194702
#   time_this_iter_s: 0.6579313278198242
#   time_total_s: 9.339545965194702
#   timestamp: 1666244579
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 067b0708
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_08d986fa:
#   date: 2022-10-20_05-43-00
#   done: false
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   hostname: 4dab924885ae
#   iterations_since_restore: 10
#   mean_accuracy: 0.60625
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 5.703742980957031
#   time_this_iter_s: 0.5500421524047852
#   time_total_s: 5.703742980957031
#   timestamp: 1666244580
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 08d986fa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_0b5901d0:
#   date: 2022-10-20_05-43-00
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 1
#   mean_accuracy: 0.19375
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 0.715430498123169
#   time_this_iter_s: 0.715430498123169
#   time_total_s: 0.715430498123169
#   timestamp: 1666244580
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0b5901d0
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_08d986fa:
#   date: 2022-10-20_05-43-04
#   done: true
#   experiment_id: 842d0d92f8ef473ebef3d316546cba3f
#   experiment_tag: 9_height=95.4983,lr=0.0023,momentum=0.6860,steps=100,width=12.8862
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.8
#   node_ip: 172.28.0.2
#   pid: 1123
#   time_since_restore: 10.000000238418579
#   time_this_iter_s: 0.43198537826538086
#   time_total_s: 10.000000238418579
#   timestamp: 1666244584
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 08d986fa
#   warmup_time: 0.003259420394897461
#
# Result for train_mnist_0b5901d0:
#   date: 2022-10-20_05-43-05
#   done: false
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   hostname: 4dab924885ae
#   iterations_since_restore: 15
#   mean_accuracy: 0.821875
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 5.827397108078003
#   time_this_iter_s: 0.19358468055725098
#   time_total_s: 5.827397108078003
#   timestamp: 1666244585
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: 0b5901d0
#   warmup_time: 0.004308462142944336
#
# Result for train_mnist_0b5901d0:
#   date: 2022-10-20_05-43-06
#   done: true
#   experiment_id: 48bebeafb73049e6b948fc63856d17ea
#   experiment_tag: 10_height=-55.1090,lr=0.0029,momentum=0.7133,steps=100,width=10.5164
#   hostname: 4dab924885ae
#   iterations_since_restore: 20
#   mean_accuracy: 0.859375
#   node_ip: 172.28.0.2
#   pid: 1158
#   time_since_restore: 6.828460454940796
#   time_this_iter_s: 0.20869994163513184
#   time_total_s: 6.828460454940796
#   timestamp: 1666244586
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 0b5901d0
#   warmup_time: 0.004308462142944336
# 2022-10-20 05:43:06,844	INFO tune.py:759 -- Total run time: 47.29 seconds (47.15 seconds for the tuning loop).
# Time taken: 47.33 seconds.
# Best config: Result(metrics={'mean_accuracy': 0.909375, 'done': True, 'trial_id': 'fe3210aa', 'experiment_tag': '5_height=11.4543,lr=0.0850,momentum=0.4734,steps=100,width=5.5559'}, error=None, log_dir=PosixPath('/root/ray_results/train_mnist_2022-10-20_05-42-19/train_mnist_fe3210aa_5_height=11.4543,lr=0.0850,momentum=0.4734,steps=100,width=5.5559_2022-10-20_05-42-36'))

# %%
best_params.metrics
# Out:
# {'mean_accuracy': 0.909375,
#  'time_this_iter_s': 0.3760716915130615,
#  'done': True,
#  'timesteps_total': None,
#  'episodes_total': None,
#  'training_iteration': 20,
#  'trial_id': 'fe3210aa',
#  'experiment_id': '842d0d92f8ef473ebef3d316546cba3f',
#  'date': '2022-10-20_05-42-46',
#  'timestamp': 1666244566,
#  'time_total_s': 9.796791076660156,
#  'pid': 1123,
#  'hostname': '4dab924885ae',
#  'node_ip': '172.28.0.2',
#  'config': {'steps': 100,
#   'width': 5.555917946413185,
#   'height': 11.454337658750788,
#   'lr': 0.08495958767364636,
#   'momentum': 0.4734163529887274},
#  'time_since_restore': 9.796791076660156,
#  'timesteps_since_restore': 0,
#  'iterations_since_restore': 20,
#  'warmup_time': 0.003259420394897461,
#  'experiment_tag': '5_height=11.4543,lr=0.0850,momentum=0.4734,steps=100,width=5.5559'}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f0a9061207d4> in <module>
# ----> 1 dict(**best_params)
#
# TypeError: type object argument after ** must be a mapping, not Result
